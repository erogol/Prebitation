# %% [markdown]
# https://machinelearningmastery.com/time-series-forecasting-long-short-term-memory-network-python/#comment-417989

# %%
# %load_ext autoreload
# %autoreload 2

# First step, import libraries.
import numpy as np 
import pandas as pd 
import seaborn as sb
from matplotlib import pyplot as plt
from utils import split_data, difference
# %matplotlib inline

# %%
DATA_PATH = "../data/bitcoin-historical-data/coinbaseUSD_1-min_data_2014-12-01_to_2017-10-20.csv.csv"
PRED_DAYS = 30  # num prediction days for the trained models

# %%
# Import the dataset and encode the date
df = pd.read_csv(DATA_PATH)
df['Date'] = pd.to_datetime(df['Timestamp'],unit='s').dt.date  # convert date human readable 
group = df.groupby('Date')

# %%
# plot the history
df.plot(x='Date', y='Close', figsize=[25, 10])

# %%
day_close_price = group['Weighted_Price'].last()  # not true but approximation to start
print(" # of days we have: {}".format(len(day_close_price)))
# Out:
#  # of days we have: 1021

# %%
# split data
df_train, df_test = split_data(day_close_price, 30)
# Out:
#  Train data size 991
#  Test data size 30

# %%
from sklearn.preprocessing import MinMaxScaler

# Data preprocess
X_train = difference(df_train.values)  # trend removal
X_train = X_train[:, None]

# MaxMin scale input for NN
# sc = MinMaxScaler() 
# X_train = sc.fit_transform(X_train)

# set train set and labels
y_train = X_train[1:len(X_train)]
X_train = X_train[0:len(X_train)-1]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from tqdm import tqdm

# Initialising the RNN
regressor = Sequential()

# Adding the input layer and the LSTM layer
regressor.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1), stateful=True, batch_input_shape=[1,1,1]))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
for i in range(1000):
    print(" ---- "+str(i))
    regressor.fit(X_train, y_train, epochs=1, batch_size=1, verbose=True, shuffle=False)
    regressor.reset_states()
# Out:
#  ---- 0
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3675.7279
#  ---- 1
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3674.7052
#  ---- 2
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3674.0424
#  ---- 3
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3673.4596
#  ---- 4
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3673.0025
#  ---- 5
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3672.6007
#  ---- 6
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3672.1968
#  ---- 7
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3671.7711
#  ---- 8
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3671.3881
#  ---- 9
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3671.0010
#  ---- 10
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3670.6605
#  ---- 11
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3670.3917
#  ---- 12
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3670.0788
#  ---- 13
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3669.7976
#  ---- 14
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3669.4376
#  ---- 15
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3669.1753
#  ---- 16
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3668.9450
#  ---- 17
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3668.6999
#  ---- 18
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3668.4437
#  ---- 19
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3668.2662
#  ---- 20
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3668.0725
#  ---- 21
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3667.8754
#  ---- 22
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3667.6977
#  ---- 23
# Epoch 1/1
# 989/989 [==============================] - 6s - loss: 3667.5305
#  ---- 24
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3667.3599
#  ---- 25
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3667.2026
#  ---- 26
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3667.0525
#  ---- 27
# Epoch 1/1
# 989/989 [==============================] - 7s - loss: 3666.9054
#  ---- 28
# Epoch 1/1
# 683/989 [===================>..........] - ETA: 2s - loss: 181.6142

# %%
# Making the predictions
test_set = df_test.values
test_set = difference(test_set)  # trend removal

test_set = test_set[:, None]
X_test = sc.transform(test_set)
X_test = np.reshape(X_test, (len(X_test), 1, 1))

# %%
# walk-forward validation on the test data
predictions = list()
for i in range(0,len(X_test)):
    # make one-step forecast
    X = X_test[i]
    X = X.reshape(1, 1, len(X))
    yhat = regressor.predict(X, batch_size=1)
    # invert scaling
    yhat = sc.inverse_transform(yhat)
    # invert differencing
    yhat = df_test.values[i] + yhat
    # store forecast
    predictions.append(yhat[0][0])
    expected = df_test.values[i+1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

# %%
# Visualising the results
plt.figure(figsize=(25,15), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  

plt.plot(df_test.values[1:], color = 'red', label = 'Real BTC Price')
plt.plot(predictions, color = 'blue', label = 'Predicted BTC Price')

plt.title('BTC Price Prediction', fontsize=40)
# df_test = df_test.reset_index()
# x=df_test.index
# labels = df_test['Date']
# plt.xticks(x, labels, rotation = 'vertical')
# for tick in ax.xaxis.get_major_ticks():
#     tick.label1.set_fontsize(18)
# for tick in ax.yaxis.get_major_ticks():
#     tick.label1.set_fontsize(18)
    
# plt.xlabel('Time', fontsize=40)
# plt.ylabel('BTC Price(USD)', fontsize=40)
# plt.legend(loc=2, prop={'size': 25})
# plt.show()
